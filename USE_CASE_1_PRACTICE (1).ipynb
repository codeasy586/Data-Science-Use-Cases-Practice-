# %% [markdown]
# # Titanic Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# # Data exploration

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['sex', 'embarked', 'who', 'embark_town', 'alive'], dtype='object')

# %%
df.describe(include = 'object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df[['survived','sex','age']]
# Out:
#      survived     sex   age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %%
df2 = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv' , sep='\t')

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 152                                   Meo, Mr. Alfonzo    male  55.5
# 153                    van Billiard, Mr. Austin Blyler    male  40.5
# 154                              Olsen, Mr. Ole Martin    male   NaN
# 155                        Williams, Mr. Charles Duane    male  51.0
#
# [156 rows x 3 columns]

# %%
df2[['Name','Sex','Age']].sort_values(by = 'Name')[:15]
# Out:
#                                                   Name     Sex   Age
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 4                             Allen, Mr. William Henry    male  35.0
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0
# 68                     Andersson, Miss. Erna Alexandra  female  17.0
# 13                         Andersson, Mr. Anders Johan    male  39.0
# 146       Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0
# 91                          Andreasson, Mr. Paul Edvin    male  20.0
# 144                         Andrew, Mr. Edgardo Samuel    male  18.0
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 114                              Attalah, Miss. Malake  female  17.0
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0
# 112                             Barton, Mr. David John    male  22.0
# ...

# %%
df2.shape
# Out:
# (156, 12)

# %% [markdown]
# ## How many categories are there in embarked column?

# %%
df2.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ## How many categories are there in pclass column?

# %%
df2.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## creating new column whose value is the first char from values of Cabin column

# %%
list_cabin = list(df2.Cabin)

# %%
for item in range(len(list_cabin)):
    if(type(list_cabin[item]) is not str):
        list_cabin[item] = str(list_cabin[item])
    else:
        continue

# %%
lst = []
for val in list_cabin:
    lst.append(val[0])

# %%
df2['char_cabin'] = lst

# %%
df2['char_cabin']
# Out:
# 0      n
# 1      C
# 2      n
# 3      C
# 4      n
#       ..
# 151    C
# 152    n
# 153    n
# 154    n
# 155    n
# Name: char_cabin, Length: 156, dtype: object

# %%
char_cabin = df2.Cabin.astype(str)

# %%
char_cabin = [cabin[0] for cabin in char_cabin]

# %%
df2['char_cabin'] = char_cabin

# %%
df2['char_cabin'].unique()
# Out:
# array(['n', 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Dealing with null values

# %%
df2.Age.isnull().sum()
# Out:
# 30

# %%
df2.isnull().sum().to_frame()
# Out:
#                0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age           30
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        125
# Embarked       1
# char_cabin     0

# %%
df2[df2['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
np.where(df2.Age.isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
df2.iloc[np.where(df2.Age.isnull() == True)]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df2[df2['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df2['Fare'].max()
# Out:
# 263.0

# %%
df2[df2['Fare'] == 263]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked char_cabin
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S          C
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S          C

# %%
df2[df2['Fare'] == max(df2['Fare'])]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked char_cabin
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S          C
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S          C

# %%
df2['Family'] = df2['SibSp'] + df2['Parch']

# %%
df2[['Family']].head(20)
# Out:
#     Family
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
# 5        0
# 6        0
# 7        4
# 8        2
# 9        1
# 10       2
# 11       0
# 12       0
# 13       6
# 14       0
# 15       0
# 16       5
# 17       0
# 18       1
# 19       0

# %%
df2['Family'].max()
# Out:
# 7

# %%
df2.iloc[np.where(df2.Family == max(df2.Family))]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked char_cabin  Family
# 59  11.0      5      2  CA 2144  46.9   NaN        S          n       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S          n       7

# %%
df2['Cabin'].isnull().sum()
# Out:
# 125

# %%
df2.shape
# Out:
# (156, 14)

# %% [markdown]
# ## Data Cleaning

# %%
total_values = df2.shape[0]
cabin_values = df2.Cabin.isnull().sum()

# %%
percent = (cabin_values*100)/total_values

# %%
round(percent,3)
# Out:
# 80.128

# %%
percent_values_in_embarked = round(df2.Embarked.isnull().sum()*100/df2.shape[0], 3)
percent_values_in_embarked
# Out:
# 0.641

# %%
percent_values_in_age = round(df2.Age.isnull().sum()*100/df2.shape[0],3)
percent_values_in_age
# Out:
# 19.231

# %%
df2.count().to_frame().rename(columns = {'0':'Count_values'})
# Out:
#                0
# PassengerId  156
# Survived     156
# Pclass       156
# Name         156
# Sex          156
# Age          126
# SibSp        156
# Parch        156
# Ticket       156
# Fare         156
# Cabin         31
# Embarked     155
# char_cabin   156
# Family       156

# %%
df2.drop(columns = 'Cabin',axis = 1, inplace = True)

# %%
df2.shape
# Out:
# (156, 13)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['Embarked'].fillna(value = df2['Embarked'].value_counts().idxmax(), inplace = True)

# %%
df2['Embarked'].isnull().sum()
# Out:
# 0

# %%
df2.Age.isnull().sum()
# Out:
# 30

# %%
df2.fillna(value = df2['Age'].median(), inplace = True)

# %%
df2.Age.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Common boarding point where maximum number of people boarded the ship

# %%
df2['Embarked'].value_counts().idxmax()
# Out:
# 'S'

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# char_cabin     0
# Family         0
# dtype: int64

# %% [markdown]
# ## Create column travel alone and put value 0 if family > 1 else put 1

# %%
len(df2[df2['Family']>1])
# Out:
# 34

# %%
df2['Travel Alone'] = 0

# %%
df2[df2['Travel Alone']==0].count()
# Out:
# PassengerId     156
# Survived        156
# Pclass          156
# Name            156
# Sex             156
# Age             156
# SibSp           156
# Parch           156
# Ticket          156
# Fare            156
# Embarked        156
# char_cabin      156
# Family          156
# Travel Alone    156
# dtype: int64

# %%
for i in range(len(df2)):
    if(df2['Family'].loc[i]>1):
        continue
    else:
        df2.at[i,'Travel Alone'] = 1
df2[df2['Travel Alone'] == 0]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 38            39         0       3
# 43            44         1       2
# 48            49         0       3
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 68            69         1       3
# 69            70         0       3
# 71            72         0       3
# 78            79         1       2
# 85            86         1       3
# 86            87         0       3
# 88            89         1       1
# 93            94         0       3
# 104          105         0       3
# ...

# %%
df2[df2['Travel Alone'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Which class survived the most

# %%
sns.barplot('Pclass','Survived',data = df2)

# %% [markdown]
# ## People from which boarding point survived the most

# %%
sns.barplot(df2.Embarked,df2.Survived)

# %% [markdown]
# ## People travelling alone survived the most or vice versa?

# %%
sns.barplot('Travel Alone','Survived',data = df2)

# %% [markdown]
# ## Which gender survived the most

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot('Sex','Survived',data = df2)
